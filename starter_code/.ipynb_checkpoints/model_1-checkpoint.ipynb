# %%
# Update sklearn to prevent version mismatches
# !pip install sklearn --upgrade

# %%
# install joblib. This will be used to save your model. 
# Restart your kernel after installing 
# !pip install joblib

# %%
import pandas as pd

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  koi_time0bk_err2  koi_impact  koi_impact_err1  \
# 0          0.003520         -0.003520       0.586            0.059
# 1          0.000581         -0.000581       0.969            5.126
# 2          0.000115         -0.000115       1.276            0.115
# 3          0.001130         -0.001130       0.701            0.235
# 4          0.001900         -0.001900       0.762            0.139
#
#    koi_impact_err2  koi_duration  koi_duration_err1  koi_duration_err2  \
# 0           -0.443       4.50700            0.11600           -0.11600
# 1           -0.077       1.78220            0.03410           -0.03410
# 2           -0.092       2.40641            0.00537           -0.00537
# 3           -0.478       1.65450            0.04200           -0.04200
# 4           -0.532       3.14020            0.06730           -0.06730
#
#    koi_depth  koi_depth_err1  koi_depth_err2  koi_prad  koi_prad_err1  \
# 0      874.8            35.5           -35.5      2.83           0.32
# 1    10829.0           171.0          -171.0     14.60           3.92
# 2     8079.2            12.8           -12.8     33.46           8.50
# 3      603.3            16.9           -16.9      2.75           0.88
# 4      686.0            18.7           -18.7      2.77           0.90
#
#    koi_prad_err2  koi_teq  koi_insol  koi_insol_err1  koi_insol_err2  \
# 0          -0.19      443       9.11            2.87           -1.62
# 1          -1.31      638      39.30           31.04          -10.49
# 2          -2.83     1395     891.96          668.95         -230.35
# 3          -0.35     1406     926.16          874.33         -314.24
# 4          -0.30     1160     427.65          420.33         -136.70
#
#    koi_model_snr  koi_tce_plnt_num  koi_steff  koi_steff_err1  koi_steff_err2  \
# 0           25.8                 2       5455              81             -81
# 1           76.3                 1       5853             158            -176
# 2          505.6                 1       5805             157            -174
# 3           40.9                 1       6031             169            -211
# 4           40.2                 2       6046             189            -232
#
#    koi_slogg  koi_slogg_err1  koi_slogg_err2  koi_srad  koi_srad_err1  \
# 0      4.467           0.064          -0.096     0.927          0.105
# 1      4.544           0.044          -0.176     0.868          0.233
# 2      4.564           0.053          -0.168     0.791          0.201
# 3      4.438           0.070          -0.210     1.046          0.334
# 4      4.486           0.054          -0.229     0.972          0.315
#
#    koi_srad_err2         ra        dec  koi_kepmag
# 0         -0.061  291.93423  48.141651      15.347
# 1         -0.078  297.00482  48.134129      15.436
# 2         -0.067  285.53461  48.285210      15.597
# 3         -0.133  288.75488  48.226200      15.509
# 4         -0.105  296.28613  48.224670      15.714

# %%
pd.set_option('display.max_columns', 999)
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  koi_time0bk_err2  koi_impact  koi_impact_err1  \
# 0          0.003520         -0.003520       0.586            0.059
# 1          0.000581         -0.000581       0.969            5.126
# 2          0.000115         -0.000115       1.276            0.115
# 3          0.001130         -0.001130       0.701            0.235
# 4          0.001900         -0.001900       0.762            0.139
#
#    koi_impact_err2  koi_duration  koi_duration_err1  koi_duration_err2  \
# 0           -0.443       4.50700            0.11600           -0.11600
# 1           -0.077       1.78220            0.03410           -0.03410
# 2           -0.092       2.40641            0.00537           -0.00537
# 3           -0.478       1.65450            0.04200           -0.04200
# 4           -0.532       3.14020            0.06730           -0.06730
#
#    koi_depth  koi_depth_err1  koi_depth_err2  koi_prad  koi_prad_err1  \
# 0      874.8            35.5           -35.5      2.83           0.32
# 1    10829.0           171.0          -171.0     14.60           3.92
# 2     8079.2            12.8           -12.8     33.46           8.50
# 3      603.3            16.9           -16.9      2.75           0.88
# 4      686.0            18.7           -18.7      2.77           0.90
#
#    koi_prad_err2  koi_teq  koi_insol  koi_insol_err1  koi_insol_err2  \
# 0          -0.19      443       9.11            2.87           -1.62
# 1          -1.31      638      39.30           31.04          -10.49
# 2          -2.83     1395     891.96          668.95         -230.35
# 3          -0.35     1406     926.16          874.33         -314.24
# 4          -0.30     1160     427.65          420.33         -136.70
#
#    koi_model_snr  koi_tce_plnt_num  koi_steff  koi_steff_err1  koi_steff_err2  \
# 0           25.8                 2       5455              81             -81
# 1           76.3                 1       5853             158            -176
# 2          505.6                 1       5805             157            -174
# 3           40.9                 1       6031             169            -211
# 4           40.2                 2       6046             189            -232
#
#    koi_slogg  koi_slogg_err1  koi_slogg_err2  koi_srad  koi_srad_err1  \
# 0      4.467           0.064          -0.096     0.927          0.105
# 1      4.544           0.044          -0.176     0.868          0.233
# 2      4.564           0.053          -0.168     0.791          0.201
# 3      4.438           0.070          -0.210     1.046          0.334
# 4      4.486           0.054          -0.229     0.972          0.315
#
#    koi_srad_err2         ra        dec  koi_kepmag
# 0         -0.061  291.93423  48.141651      15.347
# 1         -0.078  297.00482  48.134129      15.436
# 2         -0.067  285.53461  48.285210      15.597
# 3         -0.133  288.75488  48.226200      15.509
# 4         -0.105  296.28613  48.224670      15.714

# %%
df.shape
# Out:
# (6991, 41)

# %% [markdown]
# # Select your features (columns)

# %%
# Set features. This will also be used as your x values.
target = df["koi_disposition"] # this is y value
data = df.drop("koi_disposition", axis=1) # this is X value
feature_names = data.columns
data.head()
# Out:
#    koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0              0              0              0              0   54.418383
# 1              0              1              0              0   19.899140
# 2              0              1              0              0    1.736952
# 3              0              0              0              0    2.525592
# 4              0              0              0              0    4.134435
#
#    koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 0     2.479000e-04    -2.479000e-04   162.513840          0.003520
# 1     1.490000e-05    -1.490000e-05   175.850252          0.000581
# 2     2.630000e-07    -2.630000e-07   170.307565          0.000115
# 3     3.760000e-06    -3.760000e-06   171.595550          0.001130
# 4     1.050000e-05    -1.050000e-05   172.979370          0.001900
#
#    koi_time0bk_err2  koi_impact  koi_impact_err1  koi_impact_err2  \
# 0         -0.003520       0.586            0.059           -0.443
# 1         -0.000581       0.969            5.126           -0.077
# 2         -0.000115       1.276            0.115           -0.092
# 3         -0.001130       0.701            0.235           -0.478
# 4         -0.001900       0.762            0.139           -0.532
#
#    koi_duration  koi_duration_err1  koi_duration_err2  koi_depth  \
# 0       4.50700            0.11600           -0.11600      874.8
# 1       1.78220            0.03410           -0.03410    10829.0
# 2       2.40641            0.00537           -0.00537     8079.2
# 3       1.65450            0.04200           -0.04200      603.3
# 4       3.14020            0.06730           -0.06730      686.0
#
#    koi_depth_err1  koi_depth_err2  koi_prad  koi_prad_err1  koi_prad_err2  \
# 0            35.5           -35.5      2.83           0.32          -0.19
# 1           171.0          -171.0     14.60           3.92          -1.31
# 2            12.8           -12.8     33.46           8.50          -2.83
# 3            16.9           -16.9      2.75           0.88          -0.35
# 4            18.7           -18.7      2.77           0.90          -0.30
#
#    koi_teq  koi_insol  koi_insol_err1  koi_insol_err2  koi_model_snr  \
# 0      443       9.11            2.87           -1.62           25.8
# 1      638      39.30           31.04          -10.49           76.3
# 2     1395     891.96          668.95         -230.35          505.6
# 3     1406     926.16          874.33         -314.24           40.9
# 4     1160     427.65          420.33         -136.70           40.2
#
#    koi_tce_plnt_num  koi_steff  koi_steff_err1  koi_steff_err2  koi_slogg  \
# 0                 2       5455              81             -81      4.467
# 1                 1       5853             158            -176      4.544
# 2                 1       5805             157            -174      4.564
# 3                 1       6031             169            -211      4.438
# 4                 2       6046             189            -232      4.486
#
#    koi_slogg_err1  koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2  \
# 0           0.064          -0.096     0.927          0.105         -0.061
# 1           0.044          -0.176     0.868          0.233         -0.078
# 2           0.053          -0.168     0.791          0.201         -0.067
# 3           0.070          -0.210     1.046          0.334         -0.133
# 4           0.054          -0.229     0.972          0.315         -0.105
#
#           ra        dec  koi_kepmag
# 0  291.93423  48.141651      15.347
# 1  297.00482  48.134129      15.436
# 2  285.53461  48.285210      15.597
# 3  288.75488  48.226200      15.509
# 4  296.28613  48.224670      15.714

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
from sklearn.model_selection import train_test_split

#split training and testing data
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=84, stratify=target)

# %%
X_train.head()
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 3309              0              0              0              0   10.471619
# 5173              0              1              0              0    4.206070
# 6070              1              0              0              0   37.537859
# 2421              0              0              0              0  105.881767
# 6239              1              0              1              1   25.952291
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 3309         0.000153        -0.000153   136.287700           0.01180
# 5173         0.000003        -0.000003   132.248423           0.00050
# 6070         0.001282        -0.001282   159.736400           0.02760
# 2421         0.000131        -0.000131   156.979350           0.00101
# 6239         0.000846        -0.000846   154.868900           0.02050
#
#       koi_time0bk_err2  koi_impact  koi_impact_err1  koi_impact_err2  \
# 3309          -0.01180       0.184            0.267           -0.184
# 5173          -0.00050       0.949            0.049           -0.048
# 6070          -0.02760       0.058            0.389           -0.057
# 2421          -0.00101       0.539            0.044           -0.149
# 6239          -0.02050       0.142            0.317           -0.142
#
#       koi_duration  koi_duration_err1  koi_duration_err2  koi_depth  \
# 3309        4.5120             0.2830            -0.2830      123.9
# 5173       10.6988             0.0273            -0.0273   119810.0
# 6070        6.5130             0.5680            -0.5680      269.0
# 2421       18.0440             0.1020            -0.1020     1556.3
# 6239       10.9770             0.6220            -0.6220      557.8
#
#       koi_depth_err1  koi_depth_err2  koi_prad  koi_prad_err1  koi_prad_err2  \
# 3309            12.4           -12.4      1.74           0.27          -0.36
# 5173           275.0          -275.0    172.66          42.77         -79.42
# 6070            39.0           -39.0      1.77           0.54          -0.23
# 2421             6.3            -6.3     10.16           0.94          -1.27
# 6239            47.1           -47.1      2.03           0.51          -0.18
#
#       koi_teq  koi_insol  koi_insol_err1  koi_insol_err2  koi_model_snr  \
# 3309     1035     271.12          108.71         -110.93           11.7
# 5173     2547    9955.22         7345.63        -7507.45          508.0
# 6070      583      27.38           25.42           -9.94            8.2
# 2421      595      29.64            7.72           -8.11          301.8
# 6239      567      24.49           18.81           -6.88           14.0
#
#       koi_tce_plnt_num  koi_steff  koi_steff_err1  koi_steff_err2  koi_slogg  \
# 3309                 1       5812              78             -78      4.083
# 5173                 1       8212             229            -343      3.736
# 6070                 1       6095             190            -253      4.429
# 2421                 1       5903              79             -79      3.757
# 6239                 2       5692             177            -197      4.547
#
#       koi_slogg_err1  koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2  \
# 3309           0.182          -0.084     1.574          0.240         -0.331
# 5173           0.432          -0.108     3.185          0.789         -1.465
# 6070           0.065          -0.195     1.082          0.331         -0.142
# 2421           0.078          -0.052     2.499          0.233         -0.311
# 6239           0.032          -0.179     0.866          0.217         -0.078
#
#              ra        dec  koi_kepmag
# 3309  282.09314  42.160271      14.486
# 5173  298.47604  41.079910      11.684
# 6070  289.21732  48.204311      15.769
# 2421  291.49722  42.728481      10.775
# 6239  293.70291  38.956291      15.999

# %%
X_train.shape
# Out:
# (5243, 40)

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
# Scale your data
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras.utils import to_categorical


X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# # Train the Model

# %%
from sklearn.svm import SVC 
model = SVC(kernel='linear')
model.fit(X_train_scaled, y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='linear', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %%
print(f"Training Data Score: {model.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {model.score(X_test_scaled, y_test)}")
# Out:
# Training Data Score: 0.843410261300782
# Testing Data Score: 0.8421052631578947

# %% [markdown]
# # Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the model's parameters

# %%
# Create the GridSearchCV model
from sklearn.model_selection import GridSearchCV
param_grid = {'C': [1, 5, 10],
              'gamma': [0.0001, 0.001, 0.01]}
grid = GridSearchCV(model, param_grid, verbose=3)

# %%
# Train the model with GridSearch
grid.fit(X_train_scaled, y_train)
# Out:
# C:\Users\Owner\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [CV] C=1, gamma=0.0001 ...............................................
# [CV] ................... C=1, gamma=0.0001, score=0.833, total=   0.4s
# [CV] C=1, gamma=0.0001 ...............................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.3s remaining:    0.0s
# [CV] ................... C=1, gamma=0.0001, score=0.835, total=   0.4s
# [CV] C=1, gamma=0.0001 ...............................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.7s remaining:    0.0s
# [CV] ................... C=1, gamma=0.0001, score=0.841, total=   0.4s
# [CV] C=1, gamma=0.001 ................................................
# [CV] .................... C=1, gamma=0.001, score=0.833, total=   0.4s
# [CV] C=1, gamma=0.001 ................................................
# [CV] .................... C=1, gamma=0.001, score=0.835, total=   0.4s
# [CV] C=1, gamma=0.001 ................................................
# [CV] .................... C=1, gamma=0.001, score=0.841, total=   0.4s
# [CV] C=1, gamma=0.01 .................................................
# [CV] ..................... C=1, gamma=0.01, score=0.833, total=   0.4s
# [CV] C=1, gamma=0.01 .................................................
# [CV] ..................... C=1, gamma=0.01, score=0.835, total=   0.3s
# [CV] C=1, gamma=0.01 .................................................
# [CV] ..................... C=1, gamma=0.01, score=0.841, total=   0.4s
# [CV] C=5, gamma=0.0001 ...............................................
# [CV] ................... C=5, gamma=0.0001, score=0.856, total=   0.3s
# [CV] C=5, gamma=0.0001 ...............................................
# [CV] ................... C=5, gamma=0.0001, score=0.858, total=   0.3s
# [CV] C=5, gamma=0.0001 ...............................................
# [CV] ................... C=5, gamma=0.0001, score=0.870, total=   0.3s
# [CV] C=5, gamma=0.001 ................................................
# [CV] .................... C=5, gamma=0.001, score=0.856, total=   0.3s
# [CV] C=5, gamma=0.001 ................................................
# [CV] .................... C=5, gamma=0.001, score=0.858, total=   0.3s
# [CV] C=5, gamma=0.001 ................................................
# [CV] .................... C=5, gamma=0.001, score=0.870, total=   0.4s
# [CV] C=5, gamma=0.01 .................................................
# [CV] ..................... C=5, gamma=0.01, score=0.856, total=   0.3s
# [CV] C=5, gamma=0.01 .................................................
# [CV] ..................... C=5, gamma=0.01, score=0.858, total=   0.3s
# [CV] C=5, gamma=0.01 .................................................
# [CV] ..................... C=5, gamma=0.01, score=0.870, total=   0.3s
# [CV] C=10, gamma=0.0001 ..............................................
# [CV] .................. C=10, gamma=0.0001, score=0.866, total=   0.4s
# [CV] C=10, gamma=0.0001 ..............................................
# [CV] .................. C=10, gamma=0.0001, score=0.867, total=   0.3s
# [CV] C=10, gamma=0.0001 ..............................................
# [CV] .................. C=10, gamma=0.0001, score=0.869, total=   0.4s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ................... C=10, gamma=0.001, score=0.866, total=   0.3s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ................... C=10, gamma=0.001, score=0.867, total=   0.4s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ................... C=10, gamma=0.001, score=0.869, total=   0.4s
# [CV] C=10, gamma=0.01 ................................................
# [CV] .................... C=10, gamma=0.01, score=0.866, total=   0.3s
# [CV] C=10, gamma=0.01 ................................................
# [CV] .................... C=10, gamma=0.01, score=0.867, total=   0.3s
# [CV] C=10, gamma=0.01 ................................................
# [CV] .................... C=10, gamma=0.01, score=0.869, total=   0.4s
# [Parallel(n_jobs=1)]: Done  27 out of  27 | elapsed:    9.6s finished
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#              estimator=SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#                            decision_function_shape='ovr', degree=3,
#                            gamma='auto_deprecated', kernel='linear',
#                            max_iter=-1, probability=False, random_state=None,
#                            shrinking=True, tol=0.001, verbose=False),
#              iid='warn', n_jobs=None,
#              param_grid={'C': [1, 5, 10], 'gamma': [0.0001, 0.001, 0.01]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'C': 10, 'gamma': 0.0001}
# 0.8676330345222201

# %%
grid.score(X_train_scaled, y_train)
# Out:
# 0.8743086019454511

# %%
grid.score(X_test_scaled, y_test)
# Out:
# 0.8718535469107551

# %%
predictions = grid.predict(X_test_scaled)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, predictions))
# Out:
#                 precision    recall  f1-score   support
#
#      CANDIDATE       0.84      0.61      0.71       422
#      CONFIRMED       0.71      0.87      0.78       450
# FALSE POSITIVE       0.98      1.00      0.99       876
#
#       accuracy                           0.87      1748
#      macro avg       0.84      0.83      0.83      1748
#   weighted avg       0.88      0.87      0.87      1748

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf = rf.fit(X_train_scaled, y_train)
print(rf.score(X_train_scaled, y_train))
print(rf.score(X_test_scaled, y_test))
# Out:
# C:\Users\Owner\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# 0.9956131985504482
# 0.8947368421052632

# %%
sorted(zip(rf.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.1184771292777611, 'koi_fpflag_co'),
#  (0.10604331994280705, 'koi_fpflag_nt'),
#  (0.09843760100461321, 'koi_fpflag_ss'),
#  (0.054247986304191566, 'koi_model_snr'),
#  (0.050468799653392626, 'koi_prad_err1'),
#  (0.04883658805441012, 'koi_steff_err2'),
#  (0.03276739901692248, 'koi_prad_err2'),
#  (0.03215826429067864, 'koi_duration_err1'),
#  (0.03134670750178694, 'koi_duration_err2'),
#  (0.03128408319386071, 'koi_fpflag_ec'),
#  (0.025686108857185707, 'koi_prad'),
#  (0.023097484347224424, 'koi_impact'),
#  (0.022217595992743065, 'koi_time0bk_err2'),
#  (0.020949518028316613, 'koi_duration'),
#  (0.020220710513428403, 'koi_steff_err1'),
#  (0.019977804249399427, 'koi_period'),
#  (0.015932632678695786, 'koi_insol_err1'),
#  (0.015791119966936953, 'koi_period_err2'),
#  (0.015765145867693432, 'koi_depth_err1'),
#  (0.01385049337014226, 'koi_period_err1'),
#  (0.013808507029341135, 'koi_time0bk_err1'),
#  (0.013711950062475378, 'koi_depth'),
#  (0.013344563846913488, 'ra'),
#  (0.011832623367305612, 'koi_depth_err2'),
#  (0.011753476245076425, 'koi_time0bk'),
#  (0.011364124962573826, 'koi_insol'),
#  (0.01105869317671068, 'koi_steff'),
#  (0.010978389579302666, 'koi_teq'),
#  (0.01063050774537245, 'koi_impact_err2'),
#  (0.01017841872575119, 'dec'),
#  (0.010172288323666212, 'koi_kepmag'),
#  (0.009951754103417938, 'koi_impact_err1'),
#  (0.00964791727467971, 'koi_srad_err2'),
#  (0.009291870907043797, 'koi_slogg'),
#  (0.00907672017307719, 'koi_slogg_err2'),
#  (0.008467482267030091, 'koi_insol_err2'),
#  (0.00836144094060784, 'koi_srad'),
#  (0.008091508670798183, 'koi_srad_err1'),
#  (0.007545684738850915, 'koi_slogg_err1'),
#  (0.0031755857478147137, 'koi_tce_plnt_num')]

# %%
param_grid2 = {'n_estimators': [250, 300, 350],
              'max_depth': [125, 150, 175]}
grid2 = GridSearchCV(rf, param_grid2, verbose=3)

# %%
grid2.fit(X_train_scaled, y_train)
# Out:
# C:\Users\Owner\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [CV] max_depth=125, n_estimators=250 .................................
# [CV] ..... max_depth=125, n_estimators=250, score=0.887, total=   3.3s
# [CV] max_depth=125, n_estimators=250 .................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    3.3s remaining:    0.0s
# [CV] ..... max_depth=125, n_estimators=250, score=0.898, total=   3.5s
# [CV] max_depth=125, n_estimators=250 .................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    6.7s remaining:    0.0s
# [CV] ..... max_depth=125, n_estimators=250, score=0.895, total=   3.3s
# [CV] max_depth=125, n_estimators=300 .................................
# [CV] ..... max_depth=125, n_estimators=300, score=0.884, total=   3.9s
# [CV] max_depth=125, n_estimators=300 .................................
# [CV] ..... max_depth=125, n_estimators=300, score=0.897, total=   3.8s
# [CV] max_depth=125, n_estimators=300 .................................
# [CV] ..... max_depth=125, n_estimators=300, score=0.896, total=   3.9s
# [CV] max_depth=125, n_estimators=350 .................................
# [CV] ..... max_depth=125, n_estimators=350, score=0.889, total=   4.5s
# [CV] max_depth=125, n_estimators=350 .................................
# [CV] ..... max_depth=125, n_estimators=350, score=0.895, total=   4.9s
# [CV] max_depth=125, n_estimators=350 .................................
# [CV] ..... max_depth=125, n_estimators=350, score=0.900, total=   4.6s
# [CV] max_depth=150, n_estimators=250 .................................
# [CV] ..... max_depth=150, n_estimators=250, score=0.888, total=   3.3s
# [CV] max_depth=150, n_estimators=250 .................................
# [CV] ..... max_depth=150, n_estimators=250, score=0.900, total=   3.3s
# [CV] max_depth=150, n_estimators=250 .................................
# [CV] ..... max_depth=150, n_estimators=250, score=0.894, total=   3.6s
# [CV] max_depth=150, n_estimators=300 .................................
# [CV] ..... max_depth=150, n_estimators=300, score=0.888, total=   4.0s
# [CV] max_depth=150, n_estimators=300 .................................
# [CV] ..... max_depth=150, n_estimators=300, score=0.895, total=   3.9s
# [CV] max_depth=150, n_estimators=300 .................................
# [CV] ..... max_depth=150, n_estimators=300, score=0.895, total=   4.5s
# [CV] max_depth=150, n_estimators=350 .................................
# [CV] ..... max_depth=150, n_estimators=350, score=0.887, total=   5.4s
# [CV] max_depth=150, n_estimators=350 .................................
# [CV] ..... max_depth=150, n_estimators=350, score=0.896, total=   4.5s
# [CV] max_depth=150, n_estimators=350 .................................
# [CV] ..... max_depth=150, n_estimators=350, score=0.894, total=   4.9s
# [CV] max_depth=175, n_estimators=250 .................................
# [CV] ..... max_depth=175, n_estimators=250, score=0.888, total=   3.6s
# [CV] max_depth=175, n_estimators=250 .................................
# [CV] ..... max_depth=175, n_estimators=250, score=0.895, total=   3.4s
# [CV] max_depth=175, n_estimators=250 .................................
# [CV] ..... max_depth=175, n_estimators=250, score=0.893, total=   3.2s
# [CV] max_depth=175, n_estimators=300 .................................
# [CV] ..... max_depth=175, n_estimators=300, score=0.887, total=   3.9s
# [CV] max_depth=175, n_estimators=300 .................................
# [CV] ..... max_depth=175, n_estimators=300, score=0.896, total=   4.1s
# [CV] max_depth=175, n_estimators=300 .................................
# [CV] ..... max_depth=175, n_estimators=300, score=0.891, total=   3.9s
# [CV] max_depth=175, n_estimators=350 .................................
# [CV] ..... max_depth=175, n_estimators=350, score=0.885, total=   4.6s
# [CV] max_depth=175, n_estimators=350 .................................
# [CV] ..... max_depth=175, n_estimators=350, score=0.895, total=   4.8s
# [CV] max_depth=175, n_estimators=350 .................................
# [CV] ..... max_depth=175, n_estimators=350, score=0.892, total=   4.9s
# [Parallel(n_jobs=1)]: Done  27 out of  27 | elapsed:  1.8min finished
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#              estimator=RandomForestClassifier(bootstrap=True, class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators=10, n_jobs=None,
#                                               oob_score=False,
#                                               random_state=None, verbose=0,
#                                               warm_start=False),
#              iid='warn', n_jobs=None,
#              param_grid={'max_depth': [125, 150, 175],
#                          'n_estimators': [250, 300, 350]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %%
print(grid2.best_params_)
print(grid2.best_score_)
# Out:
# {'max_depth': 125, 'n_estimators': 350}
# 0.8945260347129506

# %%
grid2.score(X_train_scaled, y_train)
# Out:
# 1.0

# %%
grid2.score(X_test_scaled, y_test)
# Out:
# 0.9016018306636155

# %%
predictions2 = grid2.predict(X_test_scaled)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, predictions2))
# Out:
#                 precision    recall  f1-score   support
#
#      CANDIDATE       0.83      0.76      0.80       422
#      CONFIRMED       0.81      0.85      0.83       450
# FALSE POSITIVE       0.98      1.00      0.99       876
#
#       accuracy                           0.90      1748
#      macro avg       0.87      0.87      0.87      1748
#   weighted avg       0.90      0.90      0.90      1748

# %% [markdown]
# # Save the Model

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/git-bash
import joblib
filename = 'random_forest_model.sav'
joblib.dump(rf, filename)
# Out:
# ['random_forest_model.sav']

# %%
import joblib
filename = 'linear_model.sav'
joblib.dump(model, filename)
# Out:
# ['linear_model.sav']
